# %%
import streamlit
import pycaret
import pandas as pd

# %%
# Importing the dataset
dataset = pd.read_csv('y2.csv')
x = dataset.iloc[:, 0:2].values
y = dataset.iloc[:, -1].values
dataset.head()
# Out:
#    C-axis rear bearing  A-axis rear bearing        y2
# 0            22.202333            24.329000  0.000000
# 1            22.202333            24.329000 -2.158333
# 2            22.166000            24.281833 -1.863333
# 3            22.137833            24.244000 -2.965000
# 4            22.101000            24.200167 -1.991667

# %%
from pycaret.regression import *
s = setup(dataset, target = 'y2', session_id=123,
         normalize = True,
           polynomial_features = True, trigonometry_features = True,
           feature_interaction=True, 
           bin_numeric_features= ['C-axis rear bearing', 'A-axis rear bearing'])
# Out:
# <style  type="text/css" >
# #T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow27_col1,#T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow37_col1,#T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow42_col1,#T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow45_col1,#T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow47_col1,#T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow53_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow1_col1" class="data row1 col1" >y2</td>
#             </tr>
#             <tr>
#                         <th id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0clevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow2_col0" class="data row2 col0" >Original Data</td>
#                         <td id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow2_col1" class="data row2 col1" >(271, 3)</td>
#             </tr>
#             <tr>
#                         <th id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0clevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow3_col0" class="data row3 col0" >Missing Values</td>
#                         <td id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow3_col1" class="data row3 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0clevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow4_col0" class="data row4 col0" >Numeric Features</td>
#                         <td id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow4_col1" class="data row4 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0clevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow5_col0" class="data row5 col0" >Categorical Features</td>
#                         <td id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow5_col1" class="data row5 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0clevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow6_col0" class="data row6 col0" >Ordinal Features</td>
#                         <td id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow6_col1" class="data row6 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0clevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow7_col0" class="data row7 col0" >High Cardinality Features</td>
#                         <td id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0clevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow8_col0" class="data row8 col0" >High Cardinality Method</td>
#                         <td id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow8_col1" class="data row8 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0clevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow9_col0" class="data row9 col0" >Transformed Train Set</td>
#                         <td id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow9_col1" class="data row9 col1" >(189, 26)</td>
#             </tr>
#             <tr>
#                         <th id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0clevel0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow10_col0" class="data row10 col0" >Transformed Test Set</td>
#                         <td id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow10_col1" class="data row10 col1" >(82, 26)</td>
#             </tr>
#             <tr>
#                         <th id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0clevel0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#                         <td id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow11_col1" class="data row11 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0clevel0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow12_col0" class="data row12 col0" >Stratify Train-Test</td>
#                         <td id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow12_col1" class="data row12 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0clevel0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow13_col0" class="data row13 col0" >Fold Generator</td>
#                         <td id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow13_col1" class="data row13 col1" >KFold</td>
#             </tr>
#             <tr>
#                         <th id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0clevel0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow14_col0" class="data row14 col0" >Fold Number</td>
#                         <td id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow14_col1" class="data row14 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0clevel0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow15_col0" class="data row15 col0" >CPU Jobs</td>
#                         <td id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow15_col1" class="data row15 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0clevel0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow16_col0" class="data row16 col0" >Use GPU</td>
#                         <td id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow16_col1" class="data row16 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0clevel0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow17_col0" class="data row17 col0" >Log Experiment</td>
#                         <td id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0crow17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_db59db5a_f45c_11ed_a6ae_50ebf657bf0clevel0_row18" class="row_
# 2023-05-17 10:45:17.265 INFO    logs: create_model_container: 0
# 2023-05-17 10:45:17.266 INFO    logs: master_model_container: 0
# 2023-05-17 10:45:17.266 INFO    logs: display_container: 1
# 2023-05-17 10:45:17.269 INFO    logs: Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=True, features_todrop=[],
#                                       id_columns=[], ml_usecase='regression',
#                                       numerical_features=[], target='y2',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeric_strategy='mea...
#                 ('dummy', Dummify(target='y2')),
#                 ('fix_perfect', Remove_100(target='y2')),
#                 ('clean_names', Clean_Colum_Names()),
#                 ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                 ('dfs',
#                  DFS_Classic(interactions=['multiply'], ml_usecase='regression',
#                              n_jobs=-1, random_state=123, subclass='binary',
#                              target='y2',
#                              top_features_to_pick_percentage=None)),
#                 ('pca', 'passthrough')],
#          verbose=False)
# 2023-05-17 10:45:17.269 INFO    logs: setup() succesfully completed......................................

# %%
best = compare_models()
# Out:
# <style  type="text/css" >
#     #T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0c th {
#           text-align: left;
#     }#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow0_col0,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow0_col5,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow0_col6,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow1_col0,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow1_col1,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow1_col2,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow1_col3,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow1_col4,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow1_col5,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow1_col6,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow2_col0,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow2_col1,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow2_col2,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow2_col3,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow2_col4,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow2_col5,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow3_col0,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow3_col1,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow3_col2,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow3_col3,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow3_col4,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow3_col6,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow4_col0,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow4_col1,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow4_col2,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow4_col3,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow4_col4,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow4_col5,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow4_col6,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow5_col0,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow5_col1,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow5_col2,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow5_col3,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow5_col4,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow5_col5,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow5_col6,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow6_col0,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow6_col1,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow6_col2,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow6_col3,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow6_col4,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow6_col5,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow6_col6,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow7_col0,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow7_col1,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow7_col2,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow7_col3,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow7_col4,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow7_col5,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow7_col6,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow8_col0,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow8_col1,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow8_col2,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow8_col3,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow8_col4,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow8_col5,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow8_col6,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow9_col0,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow9_col1,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow9_col2,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow9_col3,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow9_col4,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow9_col5,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow9_col6,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow10_col0,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow10_col1,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow10_col2,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow10_col3,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow10_col4,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow10_col5,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow10_col6,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow11_col0,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow11_col1,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow11_col2,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow11_col3,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow11_col4,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow11_col5,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow11_col6,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow12_col0,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow12_col1,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow12_col2,#T_e47a39 ...
#             text-align:  left;
#             text-align:  left;
#         }#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow0_col1,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow0_col2,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow0_col3,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow0_col4,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow2_col6,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow3_col5{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow0_col7,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow1_col7,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow2_col7,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow3_col7,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow5_col7,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow7_col7,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow10_col7,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow11_col7,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow12_col7,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow13_col7,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow14_col7,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow15_col7,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow16_col7,#T_e47a39ca_f45c_11ed_8dd3_50ebf657bf0crow18_col7{
#             text-align:  left;
#             text-align:  left;
#             background
# 2023-05-17 10:45:32.578 INFO    logs: create_model_container: 20
# 2023-05-17 10:45:32.578 INFO    logs: master_model_container: 20
# 2023-05-17 10:45:32.579 INFO    logs: display_container: 2
# 2023-05-17 10:45:32.579 INFO    logs: BayesianRidge(alpha_1=1e-06, alpha_2=1e-06, alpha_init=None,
#               compute_score=False, copy_X=True, fit_intercept=True,
#               lambda_1=1e-06, lambda_2=1e-06, lambda_init=None, n_iter=300,
#               normalize=False, tol=0.001, verbose=False)
# 2023-05-17 10:45:32.579 INFO    logs: compare_models() succesfully completed......................................

# %%
br_model = create_model('br')
# Out:
# <style  type="text/css" >
# #T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow10_col0,#T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow10_col1,#T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow10_col2,#T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow10_col3,#T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow10_col4,#T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow10_col5{
#             background:  yellow;
#         }</style><table id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr>    <tr>        <th class="index_name level0" >Fold</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow0_col0" class="data row0 col0" >0.4199</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow0_col1" class="data row0 col1" >0.3735</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow0_col2" class="data row0 col2" >0.6112</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow0_col3" class="data row0 col3" >0.3654</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow0_col4" class="data row0 col4" >0.2152</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow0_col5" class="data row0 col5" >0.4701</td>
#             </tr>
#             <tr>
#                         <th id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow1_col0" class="data row1 col0" >0.3610</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow1_col1" class="data row1 col1" >0.2617</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow1_col2" class="data row1 col2" >0.5116</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow1_col3" class="data row1 col3" >0.0345</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow1_col4" class="data row1 col4" >0.2502</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow1_col5" class="data row1 col5" >0.5339</td>
#             </tr>
#             <tr>
#                         <th id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0clevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow2_col0" class="data row2 col0" >0.5524</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow2_col1" class="data row2 col1" >0.9795</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow2_col2" class="data row2 col2" >0.9897</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow2_col3" class="data row2 col3" >0.1159</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow2_col4" class="data row2 col4" >0.2612</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow2_col5" class="data row2 col5" >0.4757</td>
#             </tr>
#             <tr>
#                         <th id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0clevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow3_col0" class="data row3 col0" >0.6256</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow3_col1" class="data row3 col1" >0.7674</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow3_col2" class="data row3 col2" >0.8760</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow3_col3" class="data row3 col3" >0.1230</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow3_col4" class="data row3 col4" >0.2911</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow3_col5" class="data row3 col5" >0.7321</td>
#             </tr>
#             <tr>
#                         <th id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0clevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow4_col0" class="data row4 col0" >0.6168</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow4_col1" class="data row4 col1" >1.1315</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow4_col2" class="data row4 col2" >1.0637</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow4_col3" class="data row4 col3" >0.1336</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow4_col4" class="data row4 col4" >0.2539</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow4_col5" class="data row4 col5" >0.4802</td>
#             </tr>
#             <tr>
#                         <th id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0clevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow5_col0" class="data row5 col0" >0.8015</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow5_col1" class="data row5 col1" >1.5200</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow5_col2" class="data row5 col2" >1.2329</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow5_col3" class="data row5 col3" >-0.0457</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow5_col4" class="data row5 col4" >0.2964</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow5_col5" class="data row5 col5" >1.6817</td>
#             </tr>
#             <tr>
#                         <th id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0clevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow6_col0" class="data row6 col0" >0.8266</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow6_col1" class="data row6 col1" >2.1111</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow6_col2" class="data row6 col2" >1.4530</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow6_col3" class="data row6 col3" >0.0229</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow6_col4" class="data row6 col4" >0.3845</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow6_col5" class="data row6 col5" >0.7920</td>
#             </tr>
#             <tr>
#                         <th id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0clevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow7_col0" class="data row7 col0" >0.5307</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow7_col1" class="data row7 col1" >0.9652</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow7_col2" class="data row7 col2" >0.9825</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow7_col3" class="data row7 col3" >-0.0599</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow7_col4" class="data row7 col4" >0.2288</td>
#                         <td id="T_3cfe61c6_f45d_11ed_953c_50ebf657bf0crow7_col5" class="data row7 col5" >0.5245</td>
#             </tr>
#             <tr>
# 2023-05-17 10:48:01.081 INFO    logs: create_model_container: 21
# 2023-05-17 10:48:01.081 INFO    logs: master_model_container: 21
# 2023-05-17 10:48:01.082 INFO    logs: display_container: 3
# 2023-05-17 10:48:01.082 INFO    logs: BayesianRidge(alpha_1=1e-06, alpha_2=1e-06, alpha_init=None,
#               compute_score=False, copy_X=True, fit_intercept=True,
#               lambda_1=1e-06, lambda_2=1e-06, lambda_init=None, n_iter=300,
#               normalize=False, tol=0.001, verbose=False)
# 2023-05-17 10:48:01.083 INFO    logs: create_model() succesfully completed......................................

# %%
evaluate_model(br_model)
# Out:
# 2023-05-17 10:48:27.779 INFO    logs: Initializing evaluate_model()
# 2023-05-17 10:48:27.779 INFO    logs: evaluate_model(use_train_data=False, groups=None, feature_name=None, plot_kwargs=None, fit_kwargs=None, fold=None, estimator=BayesianRidge(alpha_1=1e-06, alpha_2=1e-06, alpha_init=None,
#               compute_score=False, copy_X=True, fit_intercept=True,
#               lambda_1=1e-06, lambda_2=1e-06, lambda_init=None, n_iter=300,
#               normalize=False, tol=0.001, verbose=False))
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
predict_model(br_model)
# Out:
# 2023-05-17 10:48:31.896 INFO    logs: Initializing predict_model()
# 2023-05-17 10:48:31.897 INFO    logs: predict_model(drift_kwargs=None, display=None, ml_usecase=MLUsecase.REGRESSION, verbose=True, round=4, raw_score=False, drift_report=False, encoded_labels=True, probability_threshold=None, estimator=BayesianRidge(alpha_1=1e-06, alpha_2=1e-06, alpha_init=None,
#               compute_score=False, copy_X=True, fit_intercept=True,
#               lambda_1=1e-06, lambda_2=1e-06, lambda_init=None, n_iter=300,
#               normalize=False, tol=0.001, verbose=False))
# 2023-05-17 10:48:31.897 INFO    logs: Checking exceptions
# 2023-05-17 10:48:31.898 INFO    logs: Preloading libraries
# 2023-05-17 10:48:31.898 INFO    logs: Preparing display monitor
# <style  type="text/css" >
# </style><table id="T_4f5e7f88_f45d_11ed_8484_50ebf657bf0c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4f5e7f88_f45d_11ed_8484_50ebf657bf0clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4f5e7f88_f45d_11ed_8484_50ebf657bf0crow0_col0" class="data row0 col0" >Bayesian Ridge</td>
#                         <td id="T_4f5e7f88_f45d_11ed_8484_50ebf657bf0crow0_col1" class="data row0 col1" >0.7172</td>
#                         <td id="T_4f5e7f88_f45d_11ed_8484_50ebf657bf0crow0_col2" class="data row0 col2" >1.2777</td>
#                         <td id="T_4f5e7f88_f45d_11ed_8484_50ebf657bf0crow0_col3" class="data row0 col3" >1.1303</td>
#                         <td id="T_4f5e7f88_f45d_11ed_8484_50ebf657bf0crow0_col4" class="data row0 col4" >0.1158</td>
#                         <td id="T_4f5e7f88_f45d_11ed_8484_50ebf657bf0crow0_col5" class="data row0 col5" >0.3453</td>
#                         <td id="T_4f5e7f88_f45d_11ed_8484_50ebf657bf0crow0_col6" class="data row0 col6" >1.9971</td>
#             </tr>
#     </tbody></table>
#     C-axis rear bearing  A-axis rear bearing        y2     Label
# 0              1.309626             0.097806 -0.663333 -0.951795
# 1             -0.788944             0.485770 -0.605000 -1.332933
# 2              1.264209             0.064707 -0.381667 -0.943298
# 3             -1.215513            -0.158341 -4.438334 -1.118643
# 4              0.329160             1.072709 -1.441667 -1.450149
# ..                  ...                  ...       ...       ...
# 77             1.424695             0.231621 -0.155000 -0.993484
# 78             1.788913             0.807556 -1.835000 -1.186933
# 79            -1.041457            -0.185641  0.931667 -1.089000
# 80             0.398689            -0.788860  0.181667 -0.691451
# 81             0.939548             1.656702 -1.668333 -1.620508
#
# [82 rows x 4 columns]

# %%
save_model(br_model, model_name = 'Bayesian Ridge')
# Out:
# 2023-05-17 10:48:45.142 INFO    logs: Initializing save_model()
# 2023-05-17 10:48:45.143 INFO    logs: save_model(kwargs={}, verbose=True, prep_pipe_=Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=True, features_todrop=[],
#                                       id_columns=[], ml_usecase='regression',
#                                       numerical_features=[], target='y2',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeric_strategy='mea...
#                                                   random_state_quantile=123,
#                                                   target='y2')),
#                 ('binn', 'passthrough'), ('rem_outliers', 'passthrough'),
#                 ('cluster_all', 'passthrough'), ('dummy', Dummify(target='y2')),
#                 ('fix_perfect', Remove_100(target='y2')),
#                 ('clean_names', Clean_Colum_Names()),
#                 ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                 ('dfs', 'passthrough'), ('pca', 'passthrough')],
#          verbose=False), model_name=Bayesian Ridge, model=BayesianRidge(alpha_1=1e-06, alpha_2=1e-06, alpha_init=None,
#               compute_score=False, copy_X=True, fit_intercept=True,
#               lambda_1=1e-06, lambda_2=1e-06, lambda_init=None, n_iter=300,
#               normalize=False, tol=0.001, verbose=False))
# 2023-05-17 10:48:45.143 INFO    logs: Adding model into prep_pipe
# 2023-05-17 10:48:45.151 INFO    logs: Bayesian Ridge.pkl saved in current working directory
# 2023-05-17 10:48:45.155 INFO    logs: Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=True, features_todrop=[],
#                                       id_columns=[], ml_usecase='regression',
#                                       numerical_features=[], target='y2',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeric_strategy='mea...
#                 ('clean_names', Clean_Colum_Names()),
#                 ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                 ('dfs', 'passthrough'), ('pca', 'passthrough'),
#                 ['trained_model',
#                  BayesianRidge(alpha_1=1e-06, alpha_2=1e-06, alpha_init=None,
#                                compute_score=False, copy_X=True,
#                                fit_intercept=True, lambda_1=1e-06,
#                                lambda_2=1e-06, lambda_init=None, n_iter=300,
#                                normalize=False, tol=0.001, verbose=False)]],
#          verbose=False)
# 2023-05-17 10:48:45.155 INFO    logs: save_model() successfully completed......................................
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=[], target='y2',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_strategy='mea...
#                  ('clean_names', Clean_Colum_Names()),
#                  ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                  ('dfs', 'passthrough'), ('pca', 'passthrough'),
#                  ['trained_model',
#                   BayesianRidge(alpha_1=1e-06, alpha_2=1e-06, alpha_init=None,
#                                 compute_score=False, copy_X=True,
#                                 fit_intercept=True, lambda_1=1e-06,
#                                 lambda_2=1e-06, lambda_init=None, n_iter=300,
#                                 normalize=False, tol=0.001, verbose=False)]],
#           verbose=False),
#  'Bayesian Ridge.pkl')

# %%
from pycaret.regression import load_model, predict_model
import streamlit as st
import pandas as pd
import numpy as np


def predict_quality(model, dataset):
    
    predictions_data = predict_model(estimator = model, data = dataset)
    return predictions_data['Label'][0]
    
model = load_model('Bayesian Ridge')


st.title('Wine Quality Classifier Web App')
st.write('This is a web app to classify the quality of your wine based on\
         several features that you can see in the sidebar. Please adjust the\
         value of each feature. After that, click on the Predict button at the bottom to\
         see the prediction of the .')
# Out:
# 2023-05-17 10:48:49.032 INFO    logs: Initializing load_model()
# 2023-05-17 10:48:49.033 INFO    logs: load_model(verbose=True, authentication=None, platform=None, model_name=Bayesian Ridge)
# 2023-05-17 10:48:49.201
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\users\user\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# Transformation Pipeline and Model Successfully Loaded

# %%
C_axis_rear_bearing = st.number_input(label = 'C-axis_rear_bearing', min_value = 0.0,
                          max_value = 100.00 ,
                          value = 20.0,
                          step = 0.1)

A_axis_rear_bearing = st.sidebar.slider(label = 'A-axis rear bearing', min_value = 0.0,
                          max_value = 100.00 ,
                          value = 20.0,
                          step = 1.0)

# %%
features = {'C-axis rear bearing': C_axis_rear_bearing, 'A-axis rear bearing': A_axis_rear_bearing
        
            }
 

features_df  = pd.DataFrame([features])

st.table(features_df)  

if st.button('Predict'):
    
    prediction = predict_quality(model, features_df)
    
    st.write(' Based on feature values, your wine quality is '+ str(prediction))
