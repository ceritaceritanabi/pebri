# %%
import streamlit
import pycaret
import pandas as pd

# %%
# Importing the dataset
df = pd.read_csv('y2.csv')
x = df.iloc[:, 0:2].values
y = df.iloc[:, -1].values
df.head()
# Out:
#    C-axis rear bearing  A-axis rear bearing        y2
# 0            22.202333            24.329000  0.000000
# 1            22.202333            24.329000 -2.158333
# 2            22.166000            24.281833 -1.863333
# 3            22.137833            24.244000 -2.965000
# 4            22.101000            24.200167 -1.991667

# %%
from pycaret.regression import *
s = setup(df, target = 'y2', session_id=123)
# Out:
# <style  type="text/css" >
# #T_7addd5b8_f4b4_11ed_9312_50ebf657bf0crow42_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0crow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0crow0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0crow1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0crow1_col1" class="data row1 col1" >y2</td>
#             </tr>
#             <tr>
#                         <th id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0clevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0crow2_col0" class="data row2 col0" >Original Data</td>
#                         <td id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0crow2_col1" class="data row2 col1" >(271, 3)</td>
#             </tr>
#             <tr>
#                         <th id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0clevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0crow3_col0" class="data row3 col0" >Missing Values</td>
#                         <td id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0crow3_col1" class="data row3 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0clevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0crow4_col0" class="data row4 col0" >Numeric Features</td>
#                         <td id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0crow4_col1" class="data row4 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0clevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0crow5_col0" class="data row5 col0" >Categorical Features</td>
#                         <td id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0crow5_col1" class="data row5 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0clevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0crow6_col0" class="data row6 col0" >Ordinal Features</td>
#                         <td id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0crow6_col1" class="data row6 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0clevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0crow7_col0" class="data row7 col0" >High Cardinality Features</td>
#                         <td id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0crow7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0clevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0crow8_col0" class="data row8 col0" >High Cardinality Method</td>
#                         <td id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0crow8_col1" class="data row8 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0clevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0crow9_col0" class="data row9 col0" >Transformed Train Set</td>
#                         <td id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0crow9_col1" class="data row9 col1" >(189, 2)</td>
#             </tr>
#             <tr>
#                         <th id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0clevel0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0crow10_col0" class="data row10 col0" >Transformed Test Set</td>
#                         <td id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0crow10_col1" class="data row10 col1" >(82, 2)</td>
#             </tr>
#             <tr>
#                         <th id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0clevel0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0crow11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#                         <td id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0crow11_col1" class="data row11 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0clevel0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0crow12_col0" class="data row12 col0" >Stratify Train-Test</td>
#                         <td id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0crow12_col1" class="data row12 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0clevel0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0crow13_col0" class="data row13 col0" >Fold Generator</td>
#                         <td id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0crow13_col1" class="data row13 col1" >KFold</td>
#             </tr>
#             <tr>
#                         <th id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0clevel0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0crow14_col0" class="data row14 col0" >Fold Number</td>
#                         <td id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0crow14_col1" class="data row14 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0clevel0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0crow15_col0" class="data row15 col0" >CPU Jobs</td>
#                         <td id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0crow15_col1" class="data row15 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0clevel0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0crow16_col0" class="data row16 col0" >Use GPU</td>
#                         <td id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0crow16_col1" class="data row16 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0clevel0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0crow17_col0" class="data row17 col0" >Log Experiment</td>
#                         <td id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0crow17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0clevel0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0crow18_col0" class="data row18 col0" >Experiment Name</td>
#                         <td id="T_7addd5b8_f4b4_11ed_9312_50ebf657bf0crow18_col1" class="data
# 2023-05-17 21:12:31.107 INFO    logs: create_model_container: 0
# 2023-05-17 21:12:31.108 INFO    logs: master_model_container: 0
# 2023-05-17 21:12:31.108 INFO    logs: display_container: 1
# 2023-05-17 21:12:31.113 INFO    logs: Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=True, features_todrop=[],
#                                       id_columns=[], ml_usecase='regression',
#                                       numerical_features=[], target='y2',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeric_strategy='mea...
#                 ('scaling', 'passthrough'), ('P_transform', 'passthrough'),
#                 ('binn', 'passthrough'), ('rem_outliers', 'passthrough'),
#                 ('cluster_all', 'passthrough'), ('dummy', Dummify(target='y2')),
#                 ('fix_perfect', Remove_100(target='y2')),
#                 ('clean_names', Clean_Colum_Names()),
#                 ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                 ('dfs', 'passthrough'), ('pca', 'passthrough')],
#          verbose=False)
# 2023-05-17 21:12:31.113 INFO    logs: setup() succesfully completed......................................

# %%
best = compare_models()
# Out:
# <style  type="text/css" >
#     #T_835845c8_f4b4_11ed_b587_50ebf657bf0c th {
#           text-align: left;
#     }#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow0_col0,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow0_col1,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow0_col5,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow0_col6,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow1_col0,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow1_col2,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow1_col3,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow1_col4,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow1_col5,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow1_col6,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow2_col0,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow2_col1,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow2_col2,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow2_col3,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow2_col4,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow2_col5,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow2_col6,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow3_col0,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow3_col1,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow3_col2,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow3_col3,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow3_col4,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow3_col5,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow3_col6,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow4_col0,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow4_col1,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow4_col2,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow4_col3,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow4_col4,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow4_col5,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow4_col6,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow5_col0,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow5_col1,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow5_col2,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow5_col3,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow5_col4,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow5_col6,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow6_col0,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow6_col1,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow6_col2,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow6_col3,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow6_col4,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow6_col5,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow7_col0,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow7_col1,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow7_col2,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow7_col3,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow7_col4,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow7_col5,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow7_col6,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow8_col0,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow8_col1,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow8_col2,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow8_col3,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow8_col4,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow8_col5,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow8_col6,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow9_col0,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow9_col1,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow9_col2,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow9_col3,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow9_col4,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow9_col5,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow9_col6,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow10_col0,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow10_col1,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow10_col2,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow10_col3,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow10_col4,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow10_col5,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow10_col6,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow11_col0,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow11_col1,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow11_col2,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow11_col3,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow11_col4,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow11_col5,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow11_col6,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow12_col0,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow12_col1,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow12_col2,#T_835845 ...
#             text-align:  left;
#             text-align:  left;
#         }#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow0_col2,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow0_col3,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow0_col4,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow1_col1,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow5_col5,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow6_col6{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow0_col7,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow1_col7,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow4_col7,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow5_col7,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow7_col7,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow8_col7,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow9_col7,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow19_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow2_col7,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow3_col7,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow6_col7,#T_835845c8_f4b4_11ed_b587_50ebf657bf0crow10_col7,#T_835845c8_f4b4_11ed_b587_50ebf657b
# 2023-05-17 21:12:45.332 INFO    logs: create_model_container: 20
# 2023-05-17 21:12:45.333 INFO    logs: master_model_container: 20
# 2023-05-17 21:12:45.333 INFO    logs: display_container: 2
# 2023-05-17 21:12:45.334 INFO    logs: OrthogonalMatchingPursuit(fit_intercept=True, n_nonzero_coefs=None,
#                           normalize=True, precompute='auto', tol=None)
# 2023-05-17 21:12:45.334 INFO    logs: compare_models() succesfully completed......................................

# %%
omp_model = create_model('omp')
# Out:
# <style  type="text/css" >
# #T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow10_col0,#T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow10_col1,#T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow10_col2,#T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow10_col3,#T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow10_col4,#T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow10_col5{
#             background:  yellow;
#         }</style><table id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr>    <tr>        <th class="index_name level0" >Fold</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow0_col0" class="data row0 col0" >0.4841</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow0_col1" class="data row0 col1" >0.3941</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow0_col2" class="data row0 col2" >0.6278</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow0_col3" class="data row0 col3" >0.3305</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow0_col4" class="data row0 col4" >0.2291</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow0_col5" class="data row0 col5" >0.5046</td>
#             </tr>
#             <tr>
#                         <th id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow1_col0" class="data row1 col0" >0.3282</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow1_col1" class="data row1 col1" >0.1728</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow1_col2" class="data row1 col2" >0.4157</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow1_col3" class="data row1 col3" >0.3625</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow1_col4" class="data row1 col4" >0.2053</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow1_col5" class="data row1 col5" >0.4419</td>
#             </tr>
#             <tr>
#                         <th id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0clevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow2_col0" class="data row2 col0" >0.5579</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow2_col1" class="data row2 col1" >0.9310</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow2_col2" class="data row2 col2" >0.9649</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow2_col3" class="data row2 col3" >0.1597</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow2_col4" class="data row2 col4" >0.2880</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow2_col5" class="data row2 col5" >0.4732</td>
#             </tr>
#             <tr>
#                         <th id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0clevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow3_col0" class="data row3 col0" >0.5828</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow3_col1" class="data row3 col1" >0.6919</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow3_col2" class="data row3 col2" >0.8318</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow3_col3" class="data row3 col3" >0.2093</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow3_col4" class="data row3 col4" >0.2947</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow3_col5" class="data row3 col5" >0.6995</td>
#             </tr>
#             <tr>
#                         <th id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0clevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow4_col0" class="data row4 col0" >0.6140</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow4_col1" class="data row4 col1" >1.1402</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow4_col2" class="data row4 col2" >1.0678</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow4_col3" class="data row4 col3" >0.1270</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow4_col4" class="data row4 col4" >0.2958</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow4_col5" class="data row4 col5" >0.4823</td>
#             </tr>
#             <tr>
#                         <th id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0clevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow5_col0" class="data row5 col0" >0.8203</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow5_col1" class="data row5 col1" >1.2935</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow5_col2" class="data row5 col2" >1.1373</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow5_col3" class="data row5 col3" >0.1101</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow5_col4" class="data row5 col4" >0.3286</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow5_col5" class="data row5 col5" >1.8946</td>
#             </tr>
#             <tr>
#                         <th id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0clevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow6_col0" class="data row6 col0" >0.8439</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow6_col1" class="data row6 col1" >2.1371</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow6_col2" class="data row6 col2" >1.4619</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow6_col3" class="data row6 col3" >0.0108</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow6_col4" class="data row6 col4" >0.4197</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow6_col5" class="data row6 col5" >0.8012</td>
#             </tr>
#             <tr>
#                         <th id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0clevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow7_col0" class="data row7 col0" >0.5246</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow7_col1" class="data row7 col1" >0.8931</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow7_col2" class="data row7 col2" >0.9450</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow7_col3" class="data row7 col3" >0.0194</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow7_col4" class="data row7 col4" >0.2511</td>
#                         <td id="T_85d7670c_f4b4_11ed_8f73_50ebf657bf0crow7_col5" class="data row7 col5" >0.5225</td>
#             </tr>
#             <tr>
# 2023-05-17 21:12:49.517 INFO    logs: create_model_container: 21
# 2023-05-17 21:12:49.518 INFO    logs: master_model_container: 21
# 2023-05-17 21:12:49.518 INFO    logs: display_container: 3
# 2023-05-17 21:12:49.519 INFO    logs: OrthogonalMatchingPursuit(fit_intercept=True, n_nonzero_coefs=None,
#                           normalize=True, precompute='auto', tol=None)
# 2023-05-17 21:12:49.519 INFO    logs: create_model() succesfully completed......................................

# %%
evaluate_model(omp_model)
# Out:
# 2023-05-17 21:12:52.599 INFO    logs: Initializing evaluate_model()
# 2023-05-17 21:12:52.600 INFO    logs: evaluate_model(use_train_data=False, groups=None, feature_name=None, plot_kwargs=None, fit_kwargs=None, fold=None, estimator=OrthogonalMatchingPursuit(fit_intercept=True, n_nonzero_coefs=None,
#                           normalize=True, precompute='auto', tol=None))
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
predict_model(omp_model)
# Out:
# 2023-05-17 21:12:55.059 INFO    logs: Initializing predict_model()
# 2023-05-17 21:12:55.060 INFO    logs: predict_model(drift_kwargs=None, display=None, ml_usecase=MLUsecase.REGRESSION, verbose=True, round=4, raw_score=False, drift_report=False, encoded_labels=True, probability_threshold=None, estimator=OrthogonalMatchingPursuit(fit_intercept=True, n_nonzero_coefs=None,
#                           normalize=True, precompute='auto', tol=None))
# 2023-05-17 21:12:55.061 INFO    logs: Checking exceptions
# 2023-05-17 21:12:55.061 INFO    logs: Preloading libraries
# 2023-05-17 21:12:55.061 INFO    logs: Preparing display monitor
# <style  type="text/css" >
# </style><table id="T_89278c8a_f4b4_11ed_a30f_50ebf657bf0c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_89278c8a_f4b4_11ed_a30f_50ebf657bf0clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_89278c8a_f4b4_11ed_a30f_50ebf657bf0crow0_col0" class="data row0 col0" >Orthogonal Matching Pursuit</td>
#                         <td id="T_89278c8a_f4b4_11ed_a30f_50ebf657bf0crow0_col1" class="data row0 col1" >0.7380</td>
#                         <td id="T_89278c8a_f4b4_11ed_a30f_50ebf657bf0crow0_col2" class="data row0 col2" >1.3007</td>
#                         <td id="T_89278c8a_f4b4_11ed_a30f_50ebf657bf0crow0_col3" class="data row0 col3" >1.1405</td>
#                         <td id="T_89278c8a_f4b4_11ed_a30f_50ebf657bf0crow0_col4" class="data row0 col4" >0.0998</td>
#                         <td id="T_89278c8a_f4b4_11ed_a30f_50ebf657bf0crow0_col5" class="data row0 col5" >0.3653</td>
#                         <td id="T_89278c8a_f4b4_11ed_a30f_50ebf657bf0crow0_col6" class="data row0 col6" >2.0572</td>
#             </tr>
#     </tbody></table>
#     C-axis rear bearing  A-axis rear bearing        y2     Label
# 0             21.488667            23.583334 -0.663333 -0.956263
# 1             21.017666            23.780001 -0.605000 -1.081535
# 2             21.465500            23.569000 -0.381667 -0.947133
# 3             20.973667            23.479000 -4.438334 -0.889805
# 4             21.173334            24.257166 -1.441667 -1.385477
# ..                  ...                  ...       ...       ...
# 77            21.553167            23.644501 -0.155000 -0.995225
# 78            21.828501            24.006666 -1.835000 -1.225915
# 79            20.990999            23.468666  0.931667 -0.883223
# 80            21.186832            23.267000  0.181667 -0.754767
# 81            21.330334            25.128000 -1.668333 -1.940177
#
# [82 rows x 4 columns]

# %%
save_model(omp_model, model_name = 'Orthogonal Matching Pursuit')
# Out:
# 2023-05-17 21:12:58.384 INFO    logs: Initializing save_model()
# 2023-05-17 21:12:58.384 INFO    logs: save_model(kwargs={}, verbose=True, prep_pipe_=Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=True, features_todrop=[],
#                                       id_columns=[], ml_usecase='regression',
#                                       numerical_features=[], target='y2',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeric_strategy='mea...
#                 ('scaling', 'passthrough'), ('P_transform', 'passthrough'),
#                 ('binn', 'passthrough'), ('rem_outliers', 'passthrough'),
#                 ('cluster_all', 'passthrough'), ('dummy', Dummify(target='y2')),
#                 ('fix_perfect', Remove_100(target='y2')),
#                 ('clean_names', Clean_Colum_Names()),
#                 ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                 ('dfs', 'passthrough'), ('pca', 'passthrough')],
#          verbose=False), model_name=Orthogonal Matching Pursuit, model=OrthogonalMatchingPursuit(fit_intercept=True, n_nonzero_coefs=None,
#                           normalize=True, precompute='auto', tol=None))
# 2023-05-17 21:12:58.385 INFO    logs: Adding model into prep_pipe
# 2023-05-17 21:12:58.392 INFO    logs: Orthogonal Matching Pursuit.pkl saved in current working directory
# 2023-05-17 21:12:58.396 INFO    logs: Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=True, features_todrop=[],
#                                       id_columns=[], ml_usecase='regression',
#                                       numerical_features=[], target='y2',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeric_strategy='mea...
#                 ('cluster_all', 'passthrough'), ('dummy', Dummify(target='y2')),
#                 ('fix_perfect', Remove_100(target='y2')),
#                 ('clean_names', Clean_Colum_Names()),
#                 ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                 ('dfs', 'passthrough'), ('pca', 'passthrough'),
#                 ['trained_model',
#                  OrthogonalMatchingPursuit(fit_intercept=True,
#                                            n_nonzero_coefs=None, normalize=True,
#                                            precompute='auto', tol=None)]],
#          verbose=False)
# 2023-05-17 21:12:58.397 INFO    logs: save_model() successfully completed......................................
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=[], target='y2',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_strategy='mea...
#                  ('cluster_all', 'passthrough'), ('dummy', Dummify(target='y2')),
#                  ('fix_perfect', Remove_100(target='y2')),
#                  ('clean_names', Clean_Colum_Names()),
#                  ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                  ('dfs', 'passthrough'), ('pca', 'passthrough'),
#                  ['trained_model',
#                   OrthogonalMatchingPursuit(fit_intercept=True,
#                                             n_nonzero_coefs=None, normalize=True,
#                                             precompute='auto', tol=None)]],
#           verbose=False),
#  'Orthogonal Matching Pursuit.pkl')

# %%
from pycaret.regression import load_model, predict_model
import streamlit as st
import pandas as pd
import numpy as np


def predict(model, df):
    
    predictions_data = predict_model(estimator = model, data = df)
    return prediction_data['label'][0]
   
    
model = load_model('Orthogonal Matching Pursuit')


st.title('Thermal Deformation Prediction')
st.write('This is a web app to predict the thermal deformation based on\
         several features that you can see in the sidebar. Please adjust the\
         value of each feature. After that, click on the Predict button at the bottom to\
         see the prediction.')

C_axis_rear_bearing = st.sidebar.slider(label = 'C-axis_rear_bearing', min_value = 0.0,
                          max_value = 100.00 ,
                          value = 20.0,
                          step = 0.1)

A_axis_rear_bearing = st.sidebar.slider(label = 'A-axis rear bearing', min_value = 0.0,
                          max_value = 100.00 ,
                          value = 20.0,
                          step = 1.0)

features = {'C-axis rear bearing': C_axis_rear_bearing, 'A-axis rear bearing': A_axis_rear_bearing
        
            }
 

features_df  = pd.DataFrame([features])

st.table(features_df)  

if st.button('Predict'):
    
    prediction = predict_model(model, features_df)
    
    st.write(' Based on feature values, the thermal deformation is '+ str(prediction))
# Out:
# 2023-05-17 22:09:02.592 INFO    logs: Initializing load_model()
# 2023-05-17 22:09:02.593 INFO    logs: load_model(verbose=True, authentication=None, platform=None, model_name=Orthogonal Matching Pursuit)
# 2023-05-17 22:09:02.613
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\users\user\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# Transformation Pipeline and Model Successfully Loaded
